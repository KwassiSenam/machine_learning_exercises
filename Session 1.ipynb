# %% [markdown]
# # Exercise 1

# %%
import pandas as pd

# %%
filename = './datasets/pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data1 = pd.read_csv(filename, names=names, delimiter=",")
data1.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
filename = './datasets/iris_proc.data.csv'
names = ['sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm', 'class']
data2 = pd.read_csv(filename, names=names, delimiter=",")
data2.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm  class
# 0                0.2      0
# 1                0.2      0
# 2                0.2      0
# 3                0.2      0
# 4                0.2      0

# %%
filename = './datasets/Churn_Modelling.csv'
data3 = pd.read_csv(filename,  delimiter=",")
data3.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
filename = './datasets/Social_Network_Ads.csv'
data4 = pd.read_csv(filename,  delimiter=",")
data4.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %% [markdown]
# # Exercise 2 : Visualization

# %% [markdown]
# ## Manipulating Data

# %%
data1['age'].max()
# Out:
# 81

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig, ((ax0, ax1))  = plt.subplots(figsize=(10,8), nrows=2, 
                                                  ncols=1,
                                                  sharex = True,
                                 )
scatter = ax0.scatter(data1['age'], data1['mass'], c=data1['class'], cmap="winter")

ax0.set(title="Diabete and Mass Levels", xlabel="Age", ylabel="Mass")
ax0.set_xlim([20,85])


scatter = ax1.scatter(data1['age'], data1['pres'], c=data1['class'], cmap="winter")
ax1.set(title="Diabete and Arterial pressure Levels", xlabel="Age", ylabel="Pres")
ax.legend(*scatter.legend_elements(), title="class")

fig.suptitle('pima-indians-diabetes-visualization', fontsize=16, fontweight='bold');

# %%
data2['class'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
fig, ((ax0, ax1))  = plt.subplots(figsize=(10,8), nrows=2, 
                                                  ncols=1,
                                                  sharex = True,
                                 )
scatter0 = ax0.scatter(data2['sepal length in cm'], data2['sepal width in cm'], c=data2['class'], cmap="winter")

ax0.set(title="Sepal", xlabel="length", ylabel="width")
ax0.legend(*scatter0.legend_elements(), title="class")
#ax0.set_xlim([20,85])


scatter1 = ax1.scatter(data2['petal length in cm'], data2['petal width in cm'], c=data2['class'], cmap="winter")
ax1.set(title="Petal", xlabel="length", ylabel="width")
ax1.legend(*scatter1.legend_elements(), title="class")

fig.suptitle('iris-plants-visualization', fontsize=16, fontweight='bold');

# %%
data3['Age'].max()
data3['Age'].min()
# Out:
# 18

# %%
data3['Balance'].max()
data3['EstimatedSalary'].max()
# Out:
# 199992.48

# %%
total_per_age = data3.groupby(['Age']).sum()
total_per_age
# Out:
#      RowNumber  CustomerId  CreditScore  Tenure     Balance  NumOfProducts  \
# Age
# 18      124120   345471878        15107     106  1741730.65             33
# 19      134689   423839758        17972     137  1903568.57             37
# 20      214353   628217868        26602     203  3041555.60             62
# 21      246345   831947324        34306     253  4024124.79             88
# 22      402499  1317539575        53470     477  5729954.90            128
# ..         ...         ...          ...     ...         ...            ...
# 83        9310    15621644          678       6   123356.63              1
# 84        6920    31451275          945      16   180115.73              2
# 85        3034    15578006          787      10        0.00              2
# 88        2459    15813303          513      10        0.00              2
# 92       13204    31425805         1458       4   247589.55              3
#
#      HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Age
# ...

# %%
total_per_age_0 = total_per_age[total_per_age['Exited'] == 0]

# %%
total_per_age_1 = total_per_age[total_per_age['Exited'] == 1]

# %%
total_per_age_0.index.values.tolist()
# Out:
# [75, 76, 77, 78, 79, 80, 81, 82, 83, 85, 88, 92]

# %%
balance_total_per_age_0 = total_per_age_0[['Balance']]
balance_total_per_age_0
# Out:
#         Balance
# Age
# 75    486651.51
# 76   1244001.68
# 77    469157.95
# 78    388764.87
# 79    169889.79
# 80         0.00
# 81    122029.15
# 82         0.00
# 83    123356.63
# 85         0.00
# 88         0.00
# 92    247589.55

# %%
balance_total_per_age_1 = total_per_age_1[['Balance']]
balance_total_per_age_1
# Out:
#         Balance
# Age
# 19   1903568.57
# 72   1568064.46
# 73    989182.96
# 74   1527876.94
# 84    180115.73

# %%
ages = data3['Age'].unique()
listy = total_per_age_0.index.values.tolist()
for a in ages:
    if a in listy:
        print("ok")
    else:
        balance_total_per_age_0 = balance_total_per_age_0.append({'Balance': 0}, ignore_index=True)
# Out:
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\575896561.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   balance_total_per_age_0 = balance_total_per_age_0.append({'Balance': 0}, ignore_index=True)
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\575896561.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   balance_total_per_age_0 = balance_total_per_age_0.append({'Balance': 0}, ignore_index=True)
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\575896561.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   balance_total_per_age_0 = balance_total_per_age_0.append({'Balance': 0}, ignore_index=True)
# ...

# %%
ages = data3['Age'].unique()
listy = total_per_age_1.index.values.tolist()
for a in ages:
    if a in listy:
        print("ok")
    else:
        balance_total_per_age_1 = balance_total_per_age_1.append({'Balance': 0}, ignore_index=True)

# %%
type(balance_total_per_age_0)
# Out:
# pandas.core.frame.DataFrame

# %%
balance_total_per_age_0 = balance_total_per_age_0.stack().tolist()
balance_total_per_age_1 = balance_total_per_age_1.stack().tolist()

# %%
estimated_salary_total_per_age_0 = total_per_age_0[['EstimatedSalary']]
estimated_salary_total_per_age_0
# Out:
#      EstimatedSalary
# Age
# 75         785168.43
# 76        1133300.67
# 77         691714.48
# 78         576397.37
# 79         609899.90
# 80         288568.56
# 81         227455.83
# 82         182055.36
# 83          92934.41
# 85         116537.96
# 88          52952.24
# 92         230000.82

# %%
estimated_salary_total_per_age_1 = total_per_age_1[['EstimatedSalary']]
estimated_salary_total_per_age_1
# Out:
#      EstimatedSalary
# Age
# 19        2638820.71
# 72        1788723.10
# 73        1306790.94
# 74        1517520.29
# 84         374720.50

# %%
ages = data3['Age'].unique()
listy = total_per_age_0.index.values.tolist()
for a in ages:
    if a in listy:
        print("ok")
    else:
        estimated_salary_total_per_age_0 = estimated_salary_total_per_age_0.append({'EstimatedSalary': 0}, ignore_index=True)
# Out:
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\1887046399.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   estimated_salary_total_per_age_0 = estimated_salary_total_per_age_0.append({'EstimatedSalary': 0}, ignore_index=True)
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\1887046399.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   estimated_salary_total_per_age_0 = estimated_salary_total_per_age_0.append({'EstimatedSalary': 0}, ignore_index=True)
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\1887046399.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   estimated_salary_total_per_age_0 = estimated_salary_total_per_age_0.append({'EstimatedSalary': 0}, ignore_index=True)
# ...

# %%
ages = data3['Age'].unique()
listy = total_per_age_1.index.values.tolist()
for a in ages:
    if a in listy:
        print("ok")
    else:
        estimated_salary_total_per_age_1 = estimated_salary_total_per_age_1.append({'EstimatedSalary': 0}, ignore_index=True)
# Out:
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\260231949.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   estimated_salary_total_per_age_1 = estimated_salary_total_per_age_1.append({'EstimatedSalary': 0}, ignore_index=True)
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\260231949.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   estimated_salary_total_per_age_1 = estimated_salary_total_per_age_1.append({'EstimatedSalary': 0}, ignore_index=True)
# C:\Users\kwass\AppData\Local\Temp\ipykernel_8504\260231949.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   estimated_salary_total_per_age_1 = estimated_salary_total_per_age_1.append({'EstimatedSalary': 0}, ignore_index=True)
# ...

# %%
estimated_salary_total_per_age_0 = estimated_salary_total_per_age_0.stack().tolist()
estimated_salary_total_per_age_1 = estimated_salary_total_per_age_1.stack().tolist()

# %%
fig, ((ax0, ax1))  = plt.subplots(figsize=(10,10), nrows=2, 
                                                  ncols=1
                                 )
ax0.bar(data3['Age'].unique().tolist(), balance_total_per_age_0, label="0")
ax0.bar(data3['Age'].unique().tolist(), balance_total_per_age_1, label="1")
ax0.set(title="Balance", xlabel="Age", ylabel="Balance")
ax0.set_xlim([15,70])


ax1.bar(data3['Age'].unique().tolist(), estimated_salary_total_per_age_0, label="0")
ax1.bar(data3['Age'].unique().tolist(), estimated_salary_total_per_age_1, label="1")
ax1.set(title="Estimated Salary", xlabel="Age", ylabel="Balance")
ax1.set_xlim([15,70])

fig.suptitle('Churn Modelling', fontsize=16, fontweight='bold');

# %%
data4['Age'].min()
# Out:
# 18.0

# %%
fig, ax0 = plt.subplots(figsize=(10,8))
scatter = ax0.scatter(data4['Age'], data4['EstimatedSalary'], c=data4['Purchased'], cmap="winter")

ax0.set(title="Social_Network_Ads", xlabel="Age", ylabel="Estimated Salary")
ax0.set_xlim([15,65])
ax0.legend(*scatter.legend_elements(), title="Purchased")
